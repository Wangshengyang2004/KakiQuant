# %% [markdown]
# https://tushare.pro/document/2

# %%
pip install tushare
# Out:
# ...
#   Using cached websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.58.0
#     Uninstalling websocket-client-0.58.0:
#       Successfully uninstalled websocket-client-0.58.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tushare as ts

# %%
ts.set_token('214442c6d812a787cc8de4446b410c0ed00c6fbb54ef6aed1ecc6ebb')
pro = ts.pro_api()

# %% [markdown]
# https://tushare.pro/document/2?doc_id=104

# %%
df = pro.hs_const(hs_type='SH')
df
# Out:
#        ts_code hs_type   in_date out_date is_new
# 0    601628.SH      SH  20141117     None      1
# 1    601099.SH      SH  20141117     None      1
# 2    601808.SH      SH  20141117     None      1
# 3    601107.SH      SH  20141117     None      1
# 4    601880.SH      SH  20141117     None      1
# ..         ...     ...       ...      ...    ...
# 576  603638.SH      SH  20190617     None      1
# 577  603708.SH      SH  20190617     None      1
# 578  603712.SH      SH  20190617     None      1
# 579  603808.SH      SH  20190617     None      1
# 580  603876.SH      SH  20190617     None      1
#
# [581 rows x 5 columns]

# %% [markdown]
# https://tushare.pro/document/2?doc_id=27

# %%
df = pro.daily(ts_code='000001.SZ', start_date='20180701', end_date='20180718')
df
# Out:
#       ts_code trade_date  open  high   low  close  pre_close  change  pct_chg  \
# 0   000001.SZ   20180718  8.75  8.85  8.69   8.70       8.72   -0.02    -0.23
# 1   000001.SZ   20180717  8.74  8.75  8.66   8.72       8.73   -0.01    -0.11
# 2   000001.SZ   20180716  8.85  8.90  8.69   8.73       8.88   -0.15    -1.69
# 3   000001.SZ   20180713  8.92  8.94  8.82   8.88       8.88    0.00     0.00
# 4   000001.SZ   20180712  8.60  8.97  8.58   8.88       8.64    0.24     2.78
# 5   000001.SZ   20180711  8.76  8.83  8.68   8.78       8.98   -0.20    -2.23
# 6   000001.SZ   20180710  9.02  9.02  8.89   8.98       9.03   -0.05    -0.55
# 7   000001.SZ   20180709  8.69  9.03  8.68   9.03       8.66    0.37     4.27
# 8   000001.SZ   20180706  8.61  8.78  8.45   8.66       8.60    0.06     0.70
# 9   000001.SZ   20180705  8.62  8.73  8.55   8.60       8.61   -0.01    -0.12
# 10  000001.SZ   20180704  8.63  8.75  8.61   8.61       8.67   -0.06    -0.69
# ...

# %%
df['vwap'] = df['amount'] / df['vol'] *10
df
# Out:
#        ts_code trade_date   open   high    low  close  pre_close  change  \
# 0    600000.SH   20191231  12.32  12.38  12.21  12.37      12.34    0.03
# 1    600000.SH   20191230  12.27  12.36  12.12  12.34      12.32    0.02
# 2    600000.SH   20191227  12.25  12.43  12.25  12.32      12.29    0.03
# 3    600000.SH   20191226  12.26  12.32  12.23  12.29      12.24    0.05
# 4    600000.SH   20191225  12.29  12.29  12.20  12.24      12.28   -0.04
# ..         ...        ...    ...    ...    ...    ...        ...     ...
# 726  600000.SH   20170109  16.24  16.29  16.13  16.20      16.18    0.02
# 727  600000.SH   20170106  16.30  16.30  16.13  16.18      16.30   -0.12
# 728  600000.SH   20170105  16.30  16.38  16.24  16.30      16.33   -0.03
# 729  600000.SH   20170104  16.29  16.35  16.18  16.33      16.30    0.03
# 730  600000.SH   20170103  16.21  16.44  16.17  16.30      16.21    0.09
#
#      pct_chg        vol      amount       vwap
# ...

# %% [markdown]
# https://tushare.pro/document/2?doc_id=188

# %%
df = pro.hk_hold(trade_date='20190625', exchange='SH')
df
# Out:
#       code trade_date    ts_code  name       vol  ratio exchange
# 0    90782   20190625  600782.SH  新钢股份  81871694   2.56       SH
# 1    90783   20190625  600783.SH  鲁信创投    260435   0.03       SH
# 2    90784   20190625  600784.SH  鲁银投资     99021   0.01       SH
# 3    90785   20190625  600785.SH  新华百货       401   0.00       SH
# 4    90787   20190625  600787.SH  中储股份  95716315   4.35       SH
# ..     ...        ...        ...   ...       ...    ...      ...
# 867  90777   20190625  600777.SH  新潮能源  17277850   0.42       SH
# 868  90778   20190625  600778.SH  友好集团     54100   0.01       SH
# 869  90779   20190625  600779.SH   水井坊  40933661   8.37       SH
# 870  90780   20190625  600780.SH  通宝能源   1192996   0.10       SH
# 871  90781   20190625  600781.SH  辅仁药业   2010185   0.53       SH
#
# [872 rows x 7 columns]
